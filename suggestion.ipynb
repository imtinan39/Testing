# %%
import glob
import cv2 as cv
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
images1=[cv.imread(file) for file in sorted(glob.glob(r"C:\Users\USER\papaya\Papaya Black Spot\Gray Scale/*.png"))]

# %%
plt.imshow(images1[5])

# %%
img=images1[5]
b,g,r = cv.split(img) 
rgb_img = cv.merge([r,g,b])
gray_img = cv.cvtColor(rgb_img,cv.COLOR_RGB2GRAY)
plt.figure(figsize=(5,5))
plt.imshow(gray_img,cmap='gray')
row,col=gray_img.shape

# %%
row
# Out:
# 639

# %%
print(col)
print(np.mean(gray_img))
# Out:
# 640
# 121.54513399843505

# %%
intensity=[]

for i in range(0,row,128):
    for j in range(0,col,128):
            intensity.append(np.mean(gray_img[:i,:j]))
            if cv.equalizeHist(gray_img[:i,:j]) is None:
                               
                               continue
                               
            else:
                
                plt.figure(figsize=(5,5))
                plt.hist(gray_img[:i,:j].ravel(),256,[0,256],label=str(np.mean(img)))

# %%
intensity=[]

for i in range(0,row,128):
    for j in range(0,col,128):
            intensity.append(np.mean(gray_img[:i,:j]))
            if cv.equalizeHist(gray_img[:i,:j]) is None:
                               
                               continue
                               
            else:
                gray_img[:i,:j] = cv.equalizeHist(gray_img[:i,:j])
                intensity.append(np.mean(gray_img[:i,:j]))
                plt.figure(figsize=(5,5))
                plt.hist(gray_img[:i,:j].ravel(),256,[0,256],label=str(np.mean(img)))
            
            
            
            
plt.figure(figsize=(5,5))
plt.imshow(gray_img,cmap='gray')

# %%
print(np.mean(gray_img))
# Out:
# 122.18815532081378

# %%
len(intensity)
# Out:
# 41

# %%
np.mean(intensity)
# Out:
# nan
