# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[]
for i in range(1,31):
    x.append(i)
y=[2.15,2.029,1.942,1.914,1.846,1.821,1.786,1.773,1.75,1.724,1.705,1.668,1.654,1.641,1.625,1.605,1.585,1.568,1.548,1.535,1.524,1.506,1.497,1.488,1.473,1.465,1.452,1.442,1.425,1.41]
y1=[2.091,1.993,1.879,1.872,1.862,1.864,1.84,1.84,1.812,1.797,1.784,1.771,1.749,1.722,1.711,1.703,1.687,1.674,1.667,1.652,1.646,1.642,1.634,1.633,1.621,1.61,1.604,1.591,1.582,1.57]
plt.plot(x,y,label=" Training Loss", color='orange')
plt.plot(x,y1,label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Validation loss with pretrained weights of COCO dataset extra layer")
# Out:
# Text(0.5, 1.0, 'Validation loss with pretrained weights of COCO dataset extra layer')

# %%
x=[]
for i in range(1,31):
    x.append(i)
y=[2.763,2.657,2.552,2.482,2.429,2.381,2.342,2.297,2.266,2.229,2.21,2.191,2.182,2.164,2.141,2.112,2.084,2.066,2.047,2.03,2.015,2,1.984,1.966,1.953,1.94,1.933,1.925,1.914,1.90]
y1=[2.663,2.508,2.537,2.465,2.471,2.437,2.38,2.337,2.292,2.274,2.229,2.19,2.174,2.184,2.156,2.135,2.116,2.103,2.084,2.063,2.055,2.047,2.034,2.012,2,1.998,2,1.989,1.99,1.979]
plt.plot(x,y,label="Training Loss", color='orange')
plt.plot(x,y1,label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Validation loss with pretrained weights of Image dataset extra layer")
# Out:
# Text(0.5, 1.0, 'Validation loss with pretrained weights of Image dataset extra layer')

# %%
x=[]
for i in range(1,31):
    x.append(i)
y=[2.183,2.07,2.025,1.933,1.895,1.859,1.84,1.796,1.76,1.735,1.703,1.675,1.657,1.641,1.61,1.592,1.577,1.553,1.54,1.52,1.511,1.5,1.488,1.476,1.467,1.453,1.442,1.434,1.423,1.40]
y1=[1.993,2.085,2.003,1.974,1.965,1.992,1.889,1.83,1.813,1.778,1.763,1.752,1.738,1.764,1.758,1.753,1.736,1.729,1.711,1.689,1.68,1.674,1.671,1.656,1.645,1.632,1.633,1.634,1.628,1.62]
plt.plot(x,y,label=" Training Loss", color='orange')
plt.plot(x,y1,label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Validation loss with pretrained weights of COCO dataset")
# Out:
# Text(0.5, 1.0, 'Validation loss with pretrained weights of COCO dataset')

# %%
x=[]
for i in range(1,31):
    x.append(i)
y=[2.645,2.532,2.435,2.385,2.322,2.258,2.223,2.188,2.157,2.117,2.084,2.067,2.041,2.027,2.017,1.993,1.963,1.949,1.933,1.916,1.903,1.89,1.88,1.862,1.85,1.842,1.831,1.814,1.806,1.79]
y1=[2.378,2.314,2.263,2.287,2.213,2.182,2.14,2.114,2.11,2.071,2.042,2.014,2.002,1.993,1.993,1.982,1.976,1.967,1.95,1.94,1.928,1.925,1.929,1.915,1.903,1.891,1.881,1.875,1.875,1.861]
plt.plot(x,y,label=" Training Loss", color='orange')
plt.plot(x,y1,label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Validation loss with pretrained weights of ImageNet dataset")
# Out:
# Text(0.5, 1.0, 'Validation loss with pretrained weights of ImageNet dataset')
